# %% [markdown]
# <small><i>This notebook was put together by [Anderson Banihirwe](andersy005.github.io) as part of [2017 CISL/SIParCS Research Project](https://github.com/NCAR/PySpark4Climate): **PySpark for Big Atmospheric & Oceanic Data Analysis**</i></small>

# %% [markdown]
# <h1 align="center"> El Niño Index Calculation </h1>

# %% [markdown]
# # Table of Contents
#
# - [Introduction](#Introduction)
# - [Import Packages](#Import-Packages)
# - [PySpark Session](#PySpark-Session)
# - [Data](#Data)
# - [netCDF4 - Spark's RDD](#Read-Data-with-H5Spark)
# - [RDD Exploration](#RDD-Exploration)
# - [Transform rdd by masking _FillValue](#Transform-rdd-by-masking-_FillValue)
# - [Global mean Temperature Calculation and plotting](#Global-mean-Temperature-Calculation-and-plotting)
# - [Calculate 3 months running mean with ```Pandas```](#Calculate-3-months-running-mean-with-Pandas)
# - [Calculate the anomalies](#Calculate-the-anomalies)

# %% [markdown]
# # Introduction
#
# This notebook will introduce **El Niño Index Calculation ** using PySpark to parallelize a number of tasks like calculation of means, etc.
#
# NOAA's operational definitions of El Niño and La Niña conditions are based upon the Oceanic Niño Index [ONI]. The ONI is defined as the 3-month running means of SST anomalies in the Niño 3.4 region [5N-5S, 120-170W].

# %% [markdown]
# # Import Packages

# %%
# Hide warnings if there are any
import warnings
warnings.filterwarnings('ignore')

from pyspark.sql import SparkSession
from pyspark import SparkConf
import read
import numpy as np
from __future__ import print_function
import h5py
from glob import glob
import pandas as pd

# %matplotlib inline
import matplotlib
matplotlib.style.use('ggplot')
import matplotlib.pyplot as plt
import os
import sys

# %% [markdown]
# # PySpark Session

# %%
spark = SparkSession.builder.appName("el-nino-index").getOrCreate()
sc = spark.sparkContext

# %%
sc.addPyFile("/glade/p/work/abanihi/h5spark/src/main/python/h5spark/read.py")

# %%
# Print some information about Spark's configuration
print(SparkConf().toDebugString())
# Out:
# spark.app.name=el-nino-index
# spark.master=spark://ys6017-ib:7077
# spark.submit.deployMode=client

# %% [markdown]
# # Data
#
# [**NCEP Version 2.0 OI Global SST and NCDC Version 4.0 Extended Reconstructed SST Analyses**](https://rda.ucar.edu/datasets/ds277.0/)
#
# In this particular case, **the NCDC ERSST Version 4** was used. The NCDC ERSST Version 4 is a monthly 2 degree global analysis for 1854 through 2016. EOF methods are used to create these grids using marine surface data (ICOADS).

# %%
# Get the list of files
filelist = sorted(glob("/glade/u/home/abanihi/data/NCEP-OI-NC4/*.nc"))

# %%
print(len(filelist))
print(filelist[0])
# Out:
# 1956
# /glade/u/home/abanihi/data/NCEP-OI-NC4/ersst.v4.185401.nc

# %% [markdown]
# There are 1956 files for months from 01-01-1854 to 12-31-2016. Each file contains monthly means for a particular month.

# %%
# Explore file metadata with ncdump
# !ncdump -h /glade/u/home/abanihi/data/NCEP-OI-NC4/ersst.v4.185401.nc
# Out:
# netcdf ersst.v4.185401 {
# dimensions:
# 	time = 1 ;
# 	zlev = 1 ;
# 	lat = 89 ;
# 	lon = 180 ;
# 	nv = 2 ;
# variables:
# 	short anom(time, zlev, lat, lon) ;
# 		anom:long_name = "Extended reconstructed SST anomalies" ;
# 		anom:units = "degree_C" ;
# 		anom:_FillValue = -999s ;
# 		anom:add_offset = 0.f ;
# 		anom:scale_factor = 0.01f ;
# 		anom:valid_min = -1200s ;
# 		anom:valid_max = 1200s ;
# 	float lat(lat) ;
# 		lat:long_name = "Latitude" ;
# 		lat:standard_name = "latitude" ;
# 		lat:axis = "Y" ;
# 		lat:bounds = "lat_bnds" ;
# 		lat:units = "degrees_north" ;
# 		lat:grids = "Uniform grid from -88 to 88 by 2" ;
# 	float lat_bnds(lat, nv) ;
# 		lat_bnds:units = "degrees_north" ;
# 		lat_bnds:comment = "This variable defines the latitude values at the south and north bounds of every 2-degree pixel" ;
# 	float lon(lon) ;
# 		lon:long_name = "Longitude" ;
# 		lon:standard_name = "longitude" ;
# 		lon:axis = "X" ;
# 		lon:bounds = "lon_bnds" ;
# 		lon:units = "degrees_east" ;
# 		lon:grids = "Uniform grid from 0 to 358 by 2" ;
# 	float lon_bnds(lon, nv) ;
# 		lon_bnds:units = "degrees_east" ;
# 		lon_bnds:comment = "This variable defines the longitude values at the west and east bounds of every 2-degree pixel" ;
# 	short sst(time, zlev, lat, lon) ;
# 		sst:long_name = "Extended reconstructed sea surface temperature" ;
# 		sst:standard_name = "sea_surface_temperature" ;
# 		sst:units = "degree_C" ;
# 		sst:_FillValue = -999s ;
# 		sst:add_offset = 0.f ;
# 		sst:scale_factor = 0.01f ;
# 		sst:valid_min = -300s ;
# 		sst:valid_max = 4500s ;
# 	float time(time) ;
# 		time:long_name = "Center time of the day" ;
# 		time:standard_name = "time" ;
# 		time:axis = "T" ;
# 		time:units = "days since 1854-01-15" ;
# 		time:delta_t = "0000-01-00" ;
# 		time:avg_period = "0000-01-00" ;
# 	float zlev(zlev) ;
# 		zlev:long_name = "Depth of sea surface temperature measurements" ;
# 		zlev:standard_name = "depth" ;
# 		zlev:units = "meters" ;
# 		zlev:_CoordinateAxisType = "Height" ;
# 		zlev:comment = "Measurement depth of in situ sea surface temperature varies" ;
# 		zlev:axis = "Z" ;
# 		zlev:positive = "down" ;
#
# // global attributes:
# 		:Conventions = "CF-1.6" ;
# 		:Metadata_Conventions = "CF-1.6, Unidata Dataset Discovery v1.0" ;
# 		:metadata_link = "C00884" ;
# 		:id = "ersst.v4.185401" ;
# 		:naming_authority = "gov.noaa.ncdc" ;
# 		:title = "NOAA Extended Reconstructed Sea Surface Temperature (ERSST), Version 4 (in situ only)" ;
# 		:summary = "ERSST.v4 is developped based on v3b after revisions of 11 parameters using updated data sets and advanced knowledge of ERSST analysis" ;
# 		:institution = "NOAA/NESDIS/NCDC" ;
# 		:creator_name = "Boyin Huang" ;
# 		:creator_email = "boyin.huang@noaa.gov" ;
# 		:date_created = "2014-10-24" ;
# 		:production_version = "Beta Version 4" ;
# 		:history = "Fri Jun  9 16:14:53 2017: ncks -4 ersst.v4.185401.nc ../NCEP-OI-NC4/ersst.v4.185401.nc\nVersion 4 based on Version 3b" ;
# 		:publisher_name = "Boyin Huang" ;
# 		:publisher_email = "boyin.huang@noaa.gov" ;
# 		:publisher_url = "http://www.ncdc.noaa.gov" ;
# 		:creator_url = "http://www.ncdc.noaa.gov" ;
# 		:license = "No constraints on data access or use" ;
# 		:time_coverage_start = "1854-01-15T000000Z" ;
# 		:time_coverage_end = "1854-01-15T000000Z" ;
# 		:geospatial_lon_min = "-1.0f" ;
# 		:geospatial_lon_max = "359.0f" ;
# 		:geospatial_lat_min = "-89.0f" ;
# 		:geospatial_lat_max = "89.0f" ;
# 		:geospatial_lat_units = "degrees_north" ;
# 		:geospatial_lat_resolution = "2.0" ;
# 		:geospatial_lon_units = "degrees_east" ;
# 		:geospatial_lon_resolution = "2.0" ;
# 		:spatial_resolution = "2.0 degree grid" ;
# 		:cdm_data_type = "Grid" ;
# 		:processing_level = "L4" ;
# 		:standard_name_vocabulary = "CF Standard Name Table v27" ;
# 		:keywords = "Earth Science &gt; Oceans &gt; Ocean Temperature &gt; Sea Surface Temperature &gt" ;
# 		:keywords_vocabulary = "NASA Global Change Master Directory (GCMD) Science Keywords" ;
# 		:project = "NOAA Extended Reconstructed Sea Surface Temperature (ERSST)" ;
# 		:platform = "Ship and Buoy SSTs from ICOADS R2.5 and NCEP GTS" ;
# 		:instrument = "Conventional thermometers" ;
# 		:source = "ICOADS R2.5 SST, NCEP GTS SST, HadISST ice, NCEP ice" ;
# 		:comment = "SSTs were observed by conventional thermometers in Buckets (insulated or un-insulated canvas and wooded buckets) or Engine Room Intaker" ;
# 		:references = "Huang et al, 2014: Extended Reconstructed Sea Surface Temperatures Version 4 (ERSST.v4), Part I. Upgrades and Intercomparisons. Journal of Climate, DOI: 10.1175/JCLI-D-14-00006.1." ;
# 		:climatology = "Climatology is based on 1971-2000 SST, Xue, Y., T. M. Smith, and R. W. Reynolds, 2003: Interdecadal changes of 30-yr SST normals during 1871.2000. Journal of Climate, 16, 1601-1612." ;
# 		:description = "In situ data: ICOADS2.5 before 2007 and NCEP in situ data from 2008 to present. Ice data: HadISST ice before 2010 and NCEP ice after 2010." ;
# 		:NCO = "\"4.5.5\"" ;
# }

# %% [markdown]
# # Read Data with H5Spark
# [back to top](#Table-of-Contents)

# %%
# For H5Spark to read multiple files, we need to create a list of tuples 
# in format ```('filepath','/dataset(variable in netCDF4))```

# sea surface temperature list
files_sst = [(file_, "/sst") for file_ in filelist]
files_sst[0]
# Out:
# ('/glade/u/home/abanihi/data/NCEP-OI-NC4/ersst.v4.185401.nc', '/sst')

# %% [markdown]
# ## Helper Function to parse and read data with H5Spark

# %%
def parse_files(files):
    rdd = read.h5read(sc, files, mode='multi', partitions=12)
    return rdd

# %%
# Create a RDD
sst_rdd = parse_files(files_sst).cache()

# %% [markdown]
# # RDD Exploration

# %%
from time import time

# %%
sst_rdd.first()
# Out:
# array([[[-999, -999, -999, ..., -999, -999, -999],
#         [-999, -999, -999, ..., -999, -999, -999],
#         [-999, -999, -999, ..., -999, -999, -999],
#         ...,
#         [-180, -180, -180, ..., -180, -180, -180],
#         [-180, -180, -180, ..., -180, -180, -180],
#         [-180, -180, -180, ..., -180, -180, -180]]], dtype=int16)

# %%
# count how many elements are in our rdd
t0 = time()
total_size = sst_rdd.count()
tt = time() - t0

# %%
print("There are {} elements in the rdd".format(total_size))
print("Count done in {} seconds".format(round(tt, 3)))
# Out:
# There are 1956 elements in the rdd
# Count done in 10.081 seconds

# %%
sst_rdd.take(5)
# Out:
# [array([[[-999, -999, -999, ..., -999, -999, -999],
#          [-999, -999, -999, ..., -999, -999, -999],
#          [-999, -999, -999, ..., -999, -999, -999],
#          ...,
#          [-180, -180, -180, ..., -180, -180, -180],
#          [-180, -180, -180, ..., -180, -180, -180],
#          [-180, -180, -180, ..., -180, -180, -180]]], dtype=int16),
#  array([[[-999, -999, -999, ..., -999, -999, -999],
#          [-999, -999, -999, ..., -999, -999, -999],
#          [-999, -999, -999, ..., -999, -999, -999],
#          ...,
#          [-180, -180, -180, ..., -180, -180, -180],
#          [-180, -180, -180, ..., -180, -180, -180],
#          [-180, -180, -180, ..., -180, -180, -180]]], dtype=int16),
#  array([[[-999, -999, -999, ..., -999, -999, -999],
#          [-999, -999, -999, ..., -999, -999, -999],
#          [-999, -999, -999, ..., -999, -999, -999],
#          ...,
#          [-180, -180, -180, ..., -180, -180, -180],
#          [-180, -180, -180, ..., -180, -180, -180],
#          [-180, -180, -180, ..., -180, -180, -180]]], dtype=int16),
#  array([[[-999, -999, -999, ..., -999, -999, -999],
#          [-999, -999, -999, ..., -999, -999, -999],
#          [-999, -999, -999, ..., -999, -999, -999],
#          ...,
#          [-180, -180, -180, ..., -180, -180, -180],
#          [-180, -180, -180, ..., -180, -180, -180],
#          [-180, -180, -180, ..., -180, -180, -180]]], dtype=int16),
#  array([[[-999, -999, -999, ..., -999, -999, -999],
#          [-999, -999, -999, ..., -999, -999, -999],
#          [-999, -999, -999, ..., -999, -999, -999],
#          ...,
#          [-180, -180, -180, ..., -180, -180, -180],
#          [-180, -180, -180, ..., -180, -180, -180],
#          [-180, -180, -180, ..., -180, -180, -180]]], dtype=int16)]

# %%
print(sst_rdd.first().shape)
# Out:
# (1, 89, 180)

# %% [markdown]
#  Create a new RDD with elements  containing  values from our region of interest ```[5N-5S, 120-170W]```

# %%
roi_sst_rdd = sst_rdd.map(lambda x: x[:, 41:48, 105:121])

# %%
roi_sst_rdd.count()
# Out:
# 1956

# %%
roi_sst_rdd.first()
# Out:
# array([[[2798, 2791, 2781, 2773, 2764, 2754, 2743, 2732, 2720, 2710, 2699,
#          2690, 2679, 2674, 2671, 2666],
#         [2744, 2740, 2733, 2728, 2722, 2715, 2708, 2701, 2694, 2689, 2682,
#          2676, 2673, 2669, 2666, 2665],
#         [2684, 2683, 2679, 2676, 2671, 2667, 2663, 2659, 2656, 2653, 2650,
#          2647, 2646, 2644, 2643, 2643],
#         [2647, 2647, 2646, 2645, 2642, 2640, 2639, 2638, 2638, 2637, 2636,
#          2637, 2638, 2638, 2639, 2641],
#         [2660, 2659, 2660, 2662, 2660, 2660, 2662, 2664, 2665, 2665, 2670,
#          2680, 2679, 2683, 2692, 2701],
#         [2700, 2700, 2700, 2703, 2701, 2700, 2701, 2703, 2707, 2716, 2727,
#          2738, 2743, 2748, 2754, 2757],
#         [2727, 2728, 2725, 2725, 2724, 2721, 2719, 2723, 2729, 2741, 2754,
#          2766, 2778, 2775, 2788, 2798]]], dtype=int16)

# %%
print(roi_sst_rdd.first().shape)
# Out:
# (1, 7, 16)

# %% [markdown]
# # Transform rdd by masking _FillValue
# [back to top](#Table-of-Contents)

# %%
import numpy.ma as ma  # For masking arrays

# %%
masked_roi_sst_rdd = roi_sst_rdd.map(lambda x: ma.masked_where(x == -999, x).data)

# %%
masked_roi_sst_rdd.first()
# Out:
# array([[[2798, 2791, 2781, 2773, 2764, 2754, 2743, 2732, 2720, 2710, 2699,
#          2690, 2679, 2674, 2671, 2666],
#         [2744, 2740, 2733, 2728, 2722, 2715, 2708, 2701, 2694, 2689, 2682,
#          2676, 2673, 2669, 2666, 2665],
#         [2684, 2683, 2679, 2676, 2671, 2667, 2663, 2659, 2656, 2653, 2650,
#          2647, 2646, 2644, 2643, 2643],
#         [2647, 2647, 2646, 2645, 2642, 2640, 2639, 2638, 2638, 2637, 2636,
#          2637, 2638, 2638, 2639, 2641],
#         [2660, 2659, 2660, 2662, 2660, 2660, 2662, 2664, 2665, 2665, 2670,
#          2680, 2679, 2683, 2692, 2701],
#         [2700, 2700, 2700, 2703, 2701, 2700, 2701, 2703, 2707, 2716, 2727,
#          2738, 2743, 2748, 2754, 2757],
#         [2727, 2728, 2725, 2725, 2724, 2721, 2719, 2723, 2729, 2741, 2754,
#          2766, 2778, 2775, 2788, 2798]]], dtype=int16)

# %%
masked_roi_sst_rdd.count()
# Out:
# 1956

# %% [markdown]
# Rescale the data using the given ```scale_factor=.01f``` and ```add_offset=0.f```.

# %%
rescaled_data = masked_roi_sst_rdd.map(lambda x: x * 0.01)

# %%
rescaled_data.first()
# Out:
# array([[[ 27.98,  27.91,  27.81,  27.73,  27.64,  27.54,  27.43,  27.32,
#           27.2 ,  27.1 ,  26.99,  26.9 ,  26.79,  26.74,  26.71,  26.66],
#         [ 27.44,  27.4 ,  27.33,  27.28,  27.22,  27.15,  27.08,  27.01,
#           26.94,  26.89,  26.82,  26.76,  26.73,  26.69,  26.66,  26.65],
#         [ 26.84,  26.83,  26.79,  26.76,  26.71,  26.67,  26.63,  26.59,
#           26.56,  26.53,  26.5 ,  26.47,  26.46,  26.44,  26.43,  26.43],
#         [ 26.47,  26.47,  26.46,  26.45,  26.42,  26.4 ,  26.39,  26.38,
#           26.38,  26.37,  26.36,  26.37,  26.38,  26.38,  26.39,  26.41],
#         [ 26.6 ,  26.59,  26.6 ,  26.62,  26.6 ,  26.6 ,  26.62,  26.64,
#           26.65,  26.65,  26.7 ,  26.8 ,  26.79,  26.83,  26.92,  27.01],
#         [ 27.  ,  27.  ,  27.  ,  27.03,  27.01,  27.  ,  27.01,  27.03,
#           27.07,  27.16,  27.27,  27.38,  27.43,  27.48,  27.54,  27.57],
#         [ 27.27,  27.28,  27.25,  27.25,  27.24,  27.21,  27.19,  27.23,
#           27.29,  27.41,  27.54,  27.66,  27.78,  27.75,  27.88,  27.98]]])

# %%
rescaled_data.count()
# Out:
# 1956

# %% [markdown]
# # Global mean Temperature Calculation and plotting
# [back to top](#Table-of-Contents)
#
#
# To calculate the global mean temperature for each month, We calculate the mean temperature at each latitude for
# that month, i.e., take the simple mean of the temperatures of all longitudes at a given latitude:
#
# $$\bar{T}_{lat} = \frac{1}{nLon}\sum_{i=1}^{nLon}T_{lon, i}$$
#
#
# Once we have the mean at each latitude, take the cosine weighted mean of those, giving the mean global temperature
# for this month:
#
# $$\bar{T}_{month} = \frac{\sum_{j=1}^{nLat} \cos(lat_j) \bar{T}_{lat, j}}{\sum_{j=1}^{nLat}\cos(lat_j)}$$

# %%
lat = np.linspace(-6, 6, endpoint=True, num=7)
lat
# Out:
# array([-6., -4., -2.,  0.,  2.,  4.,  6.])

# %%
def global_mean_temp(x):
    
    # get the shape of x
    a, b, c = x.shape
    
    # Reshape x 
    x = x.reshape(a*b, c)
    
    # Find average temp for each latitude
    avg_temp_lat = np.mean(x, axis=1)
    
    # Find weighted mean of those value 
    numerator = np.sum(np.multiply(np.cos(lat), avg_temp_lat))
    denominator = np.sum(np.cos(lat))
    
    # find mean global temperature for this month
    mean_global_temp = numerator / denominator
    
    return mean_global_temp

# %%
mean_global_temp = rescaled_data.map(global_mean_temp)

# %%
mean_global_temp.count()
# Out:
# 1956

# %%
mean_global_temp.first()
# Out:
# 27.346691286750893

# %%
mean_global_temp.stats()
# Out:
# (count: 1956, mean: 27.1491187288, stdev: 0.702942796727, max: 29.0164955382, min: 24.8984679099)

# %%
# Collect all the mean_global_temperature for all the months
mean_global_temperatures = mean_global_temp.collect()

# %%
a = rescaled_data.map(lambda x: np.mean(x))
a.take(10)
# Out:
# [26.946696428571446,
#  27.124910714285708,
#  27.256160714285706,
#  27.080357142857146,
#  26.583571428571425,
#  26.454642857142851,
#  26.325178571428577,
#  26.168035714285715,
#  26.000178571428556,
#  25.721160714285723]

# %%
a.stats()
# Out:
# (count: 1956, mean: 26.5092714724, stdev: 1.01404025794, max: 29.1578571429, min: 23.6654464286)

# %% [markdown]
# **Helper Function to generate list of months from 1854 through 2016**

# %% [raw]
# import datetime as dt
# from datetime import datetime, timedelta
# from collections import OrderedDict
#
# def generate_list_of_months(dates_range):
#     """
#     - Args:  dates interval
#     - Returns: List of all the months in the given dates interval
#
#     """
#     start, end = [datetime.strptime(_, "%Y-%m-%d") for _ in dates_range]
#     list_of_months = OrderedDict(((start + timedelta(_)).strftime(r"%b-%y"), None)
#                                    for _ in xrange((end - start).days)
#                                 ).keys()
#     return list_of_months

# %% [raw]
# dates_range = ["1854-01-01", "2016-12-31"]
# list_of_months = generate_list_of_months(dates_range)

# %%
dates = pd.date_range(start="1854-01-01",end="2016-12-31", freq="1M")

# %%
dates
# Out:
# <class 'pandas.tseries.index.DatetimeIndex'>
# [1854-01-31, ..., 2016-12-31]
# Length: 1956, Freq: M, Timezone: None

# %% [markdown]
# **Create a DataFrame from mean_global_temperatures**

# %%
df = pd.DataFrame(mean_global_temperatures, index=dates, columns=["Mean Global Temperature"])

# %%
df.head(10)
# Out:
#             Mean Global Temperature
# 1854-01-31                27.346691
# 1854-02-28                27.414739
# 1854-03-31                27.517490
# 1854-04-30                27.429180
# 1854-05-31                27.261891
# 1854-06-30                27.311897
# 1854-07-31                27.247913
# 1854-08-31                27.191698
# 1854-09-30                27.083985
# 1854-10-31                26.799652

# %%
df.tail(10)
# Out:
#             Mean Global Temperature
# 2016-03-31                27.760092
# 2016-04-30                27.556918
# 2016-05-31                27.416351
# 2016-06-30                27.055462
# 2016-07-31                26.921031
# 2016-08-31                26.932344
# 2016-09-30                26.885980
# 2016-10-31                26.608537
# 2016-11-30                26.415250
# 2016-12-31                26.513335

# %%
df.describe()
# Out:
#        Mean Global Temperature
# count              1956.000000
# mean                 27.149119
# std                   0.703123
# min                  24.898468
# 25%                  26.675081
# 50%                  27.179462
# 75%                  27.647833
# max                  29.016496

# %%
ax = df['Mean Global Temperature'].plot(legend=True, figsize=(16, 8))
ax.set_xlabel("Time index [Jan-01-1854; ....; Dec-31-2016]")
ax.set_ylabel("Global Mean Temperature[C]")
plt.show()

# %% [markdown]
# # Calculate 3 months running mean with Pandas
# [back to top](#Table-of-Contents)

# %%
df.head()
# Out:
#             Mean Global Temperature
# 1854-01-31                27.346691
# 1854-02-28                27.414739
# 1854-03-31                27.517490
# 1854-04-30                27.429180
# 1854-05-31                27.261891

# %%
running_mean = pd.rolling_mean(df['Mean Global Temperature'], window=3, min_periods=1)
df["Running 3 months mean"] = running_mean

# %%
df.head(10)
# Out:
#             Mean Global Temperature  Running 3 months mean
# 1854-01-31                27.346691              27.346691
# 1854-02-28                27.414739              27.380715
# 1854-03-31                27.517490              27.426307
# 1854-04-30                27.429180              27.453803
# 1854-05-31                27.261891              27.402854
# 1854-06-30                27.311897              27.334323
# 1854-07-31                27.247913              27.273900
# 1854-08-31                27.191698              27.250503
# 1854-09-30                27.083985              27.174532
# 1854-10-31                26.799652              27.025112

# %% [markdown]
# # Calculate the anomalies

# %%
anomalies = df['Mean Global Temperature'].subtract(df['Running 3 months mean'])

# %%
df["anomalies"] = anomalies

# %%
df.head(10)
# Out:
#             Mean Global Temperature  Running 3 months mean  anomalies
# 1854-01-31                27.346691              27.346691   0.000000
# 1854-02-28                27.414739              27.380715   0.034024
# 1854-03-31                27.517490              27.426307   0.091183
# 1854-04-30                27.429180              27.453803  -0.024623
# 1854-05-31                27.261891              27.402854  -0.140963
# 1854-06-30                27.311897              27.334323  -0.022426
# 1854-07-31                27.247913              27.273900  -0.025987
# 1854-08-31                27.191698              27.250503  -0.058805
# 1854-09-30                27.083985              27.174532  -0.090547
# 1854-10-31                26.799652              27.025112  -0.225459

# %%
df.describe()
# Out:
#        Mean Global Temperature  Running 3 months mean    anomalies
# count              1956.000000            1956.000000  1956.000000
# mean                 27.149119              27.149567    -0.000449
# std                   0.703123               0.645696     0.315905
# min                  24.898468              25.154537    -1.648140
# 25%                  26.675081              26.717815    -0.172575
# 50%                  27.179462              27.177379    -0.015864
# 75%                  27.647833              27.596890     0.167800
# max                  29.016496              28.911059     1.706014

# %%
ax = df['anomalies'].plot(legend=True, figsize=(16, 8))
ax.set_xlabel("Time index [Jan-01-1854; ....; Dec-31-2016]")
ax.set_ylabel("Global Mean Temperature[C]")
ax.set_title("Global Mean Temperature Anomaly")
plt.show()

# %%
ax = df.plot(legend=True, figsize=(16, 8))
ax.set_xlabel("Time index [Jan-01-1854; ....; Dec-31-2016]")
ax.set_ylabel("Global Mean Temperature[C]")
plt.show()

# %% [markdown]
# [back to top](#Table-of-Contents)
